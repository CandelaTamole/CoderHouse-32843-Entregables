# %% [markdown]
# ## CODERHOUSE - Comisión 32845
# ## Tamole Candela
#
# #### Segundo Desafio

# %% [markdown]
# ##### Dataset seleccionado:
# * **Satisfacción de pasajeros en aerolíneas:** se intentará predecir la satisfaccion de los pasajeros de arolínea en base a distintos factores.
# Algunas variables interesantes para el analisis son: La satisfaccion que sienten en la hora de arribo, los alimentos recibidos, limpieza, comodidad, servicio de check-in, clase del vuelo, distancia del viaje, servicio de on-boarding. La escala es de estas variables son del 0 a 5, donde 0 no aplica y del 1-5 de neutral a satisfecho.

# %% [markdown]
# ### Variables del DataSet:
#
# * Gender: Genero del pasajero (Femenino o Masculino)
#
# * Customer Type: el tipo de cliente (cliente fiel, cliente desleal)
#
# * Age: La edad real de los pasajeros
#
# * Type of Travel: Propósito del vuelo de los pasajeros (Viaje Personal, Viaje de Negocios)
#
# * Class: Clase de viaje en el avión de los pasajeros (Business, Eco, Eco Plus)
#
# * Flight distance: la distancia de vuelo de este viaje
#
# * Inflight wifi service: Nivel de satisfacción del servicio wifi a bordo (0: No aplicable; 1-5)
#
# * Departure/Arrival time convenient: Nivel de satisfacción de la hora de salida/llegada conveniente
#
# * Ease of Online booking: Nivel de satisfacción de la reserva en línea
#
# * Gate location: nivel de satisfacción de la ubicación de la puerta
#
# * Food and drink: Nivel de satisfacción de Alimentos y bebidas
#
# * Online boarding: Nivel de satisfacción del embarque en línea
#
# * Seat comfort: Nivel de satisfacción de Confort del asiento
#
# * Entretenimiento a bordo: Nivel de satisfacción del entretenimiento a bordo
#
# * Inflight entertainment: Nivel de satisfacción del servicio a bordo
#
# * Leg room service: Nivel de satisfacción del servicio de sala de piernas
#
# * Baggage handling: Nivel de satisfacción del manejo de equipaje
#
# * Check-in service: Nivel de satisfacción del servicio de Check-in
#
# * On-board service: Nivel de satisfacción del servicio a bordo
#
# * Cleanliness: Nivel de satisfacción de Limpieza
#
# * Departure Delay in Minutes: Minutos de retraso en la salida
#
# * Arrival Delay in Minutes: Minutos de retraso en la llegada
#
# * Satisfaction: Nivel de satisfacción de la aerolínea (Satisfacción, neutral o insatisfacción)

# %%
#Importacion de librerias:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %%
#Definicion de variable como "df" haciendo referencia nuestro data set como Data Frame
df = pd.read_csv ('/workspaces/codespaces-blank/Data/1er_dataset.csv')

# %%
#Visualizacion de nuestro Data set cargado como csv.
df
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
#Exploración de datos

df.describe(include=['O'])
# Out:
#         Gender   Customer Type   Type of Travel     Class  \
# count   103904          103904           103904    103904
# unique       2               2                2         3
# top     Female  Loyal Customer  Business travel  Business
# freq     52727           84923            71655     49665
#
#                    satisfaction
# count                    103904
# unique                        2
# top     neutral or dissatisfied
# freq                      58879

# %%
df.rename(columns={'Customer Type':'Customer_Type',
'Type of Travel':'Type_of_Travel',
'Flight Distance':'Flight_Distance',
'Inflight wifi service':'Inflight_wifi_service'},
 index={0:'cero',1:'uno'},
               inplace=True)

# %%
df
# Out:
#         Unnamed: 0      id  Gender      Customer_Type  Age   Type_of_Travel  \
# cero             0   70172    Male     Loyal Customer   13  Personal Travel
# uno              1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
df.max()
# Out:
# Unnamed: 0                                      103903
# id                                              129880
# Gender                                            Male
# Customer_Type                        disloyal Customer
# Age                                                 85
# Type_of_Travel                         Personal Travel
# Class                                         Eco Plus
# Flight_Distance                                   4983
# Inflight_wifi_service                                5
# Departure/Arrival time convenient                    5
# Ease of Online booking                               5
# Gate location                                        5
# Food and drink                                       5
# Online boarding                                      5
# Seat comfort                                         5
# Inflight entertainment                               5
# On-board service                                     5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103904 entries, cero to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer_Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type_of_Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight_Distance                    103904 non-null  int64
#  8   Inflight_wifi_service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0             id            Age  Flight_Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight_wifi_service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %%
#Importar librerias 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

#Cambiar estilos de Matplotlib
mpl.style.use ('ggplot')

# %% [markdown]
# # Gráficos con Seaborn

# %%
df.drop(['Unnamed: 0', 'id'], axis= 1, inplace= True)

# %%
words_columns = df.select_dtypes(object).columns.to_list()
number_columns = df.select_dtypes(np.number).columns.to_list()


number_columns
# Out:
# ['Age',
#  'Flight_Distance',
#  'Inflight_wifi_service',
#  'Departure/Arrival time convenient',
#  'Ease of Online booking',
#  'Gate location',
#  'Food and drink',
#  'Online boarding',
#  'Seat comfort',
#  'Inflight entertainment',
#  'On-board service',
#  'Leg room service',
#  'Baggage handling',
#  'Checkin service',
#  'Inflight service',
#  'Cleanliness',
#  'Departure Delay in Minutes',
#  'Arrival Delay in Minutes']

# %%
sns.set_context('paper', font_scale= 1.2)
sns.displot(df['Age'])

# %% [markdown]
# #### Conclusión gráfico 1:
# Podemos visualizar que el pico de cantidad de personas que viajan rondan los 40 años de edad.

# %%
sns.set_context('paper', font_scale= 1.2)
sns.boxplot(data=df, x='Cleanliness', y='Age')
# Out:
# <AxesSubplot: xlabel='Cleanliness', ylabel='Age'>

# %% [markdown]
# #### Conclusión gráfico 2:
# Podemos visualizar que el rango de edad de personas de 20-25 años es la que mas insatisfecha se encuantra en cuano al servicio de Limpieza de las aerolíneas.

# %%
sns.set_context('paper', font_scale= 1.2)
sns.catplot(x= df['Departure Delay in Minutes'])

# %% [markdown]
# #### Conclusión gráfico 3:
# El gráfico nos demuestra una gran dispersión a partir de 600 minutos (10hs), es decir, que la mayoria de los atrasos en despegues son menor a 10hs.

# %% [markdown]
# # Gráficos con Matplotlib

# %%
fig = plt.figure(figsize = (8,5))
df.satisfaction.value_counts(normalize = True).plot(kind='bar', alpha = 0.9, rot=0)
plt.title('Indicador de satisfacción (0) y (1)')
plt.show()

# %% [markdown]
# #### Conclusión gráfico 1:
# El gráfico  muestra una distribución de al rededor del 45 % y 55 % entre pasajeros neutrales o insatisfechos y pasajeros satisfechos, respectivamente.

# %%
plt.pie(df.satisfaction.value_counts(), 
labels = ["Male", "Female"], autopct = '%1.1f%%')
plt.show()

# %% [markdown]
# #### Conclusión gráfico 2:
# El gráfico  muestra una mayoría de personas masculinas que han viajado en aerolínea.

# %%
plt.scatter(df['Arrival Delay in Minutes'], 
df['Departure Delay in Minutes'], alpha = 0.7)
plt.show()

# %% [markdown]
# #### Conclusión gráfico 3:
# El gráfico  muestra como el atraso en en la partida es directamente proporcional al atraso en el arribo a destino.

# %%
# !pip install -q chart_studio
# !pip install -q bqplot
# !pip install -q pingouin
from scipy import stats
import  statsmodels.formula.api as sm
import os
# Out:
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip

# %% [markdown]
# # Entrega Nro 3
#
# ### Objetivo: Visualizar que factores influyen directamente a la satisfacción de los pasajeros de aerolínea.

# %% [markdown]
# ##### **1) ¿El tipo de viaje que realizan los pasajeros influye en la satisfacción de los mismos?**

# %%
sns.countplot(x = 'Type_of_Travel', data = df, hue= 'satisfaction',  
palette= 'Reds')
plt.title ('Personal vs Business')
# Out:
# Text(0.5, 1.0, 'Personal vs Business')

# %% [markdown]
# > Podemos concluir que las personas que utilizan las aerolíneas por viajes de negocios están mucho mas satisfechas, que las personas que las utilizan por otro motivo.

# %% [markdown]
# ##### **2) ¿La clase en la que viajan los pasajeros influye en la satisfacción de los mismos?**

# %%
sns.countplot(x = 'Class', data = df, hue= 'satisfaction',  
palette= 'Reds')
plt.title ('Economica vs Bussines')
# Out:
# Text(0.5, 1.0, 'Economica vs Bussines')

# %%
df.Class.value_counts()
# Out:
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64

# %% [markdown]
# > Podemos concluir que las personas que viajan en "Business Class" tienen un mayor grado de satisfaccion con respecto a las clases "Eco".
#
# > Respecto a "Eco plus", no podriamos concluir lo mismo ya que la cantidad de personas encuestadas, con respecto a las demás clases, es considerablemente menor.

# %%
df.columns
# Out:
# Index(['Gender', 'Customer_Type', 'Age', 'Type_of_Travel', 'Class',
#        'Flight_Distance', 'Inflight_wifi_service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df.rename(columns={'Departure/Arrival time convenient':'Departure_Arrival_time_conveniente',
'Ease of Online booking':'Online_booking',
'Gate location':'Gate_location',
'Food and drink':'Food_drink',
'Seat comfort':'Seat_comfort',
'Chekin service' : 'Chekin_service',
'Inflight entertainment':'Inflight_entertainment'},
 index={0:'cero',1:'uno'},
               inplace=True)

# %% [markdown]
# ##### **3) ¿Existe alguna relacion entre la comidad de los asientos y la limpieza?**

# %%
model1 ='Seat_comfort~Cleanliness'
lm1 = sm.ols(formula= model1, data=df).fit()
print(lm1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Seat_comfort   R-squared:                       0.460
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                 8.865e+04
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):               0.00
# Time:                        01:07:57   Log-Likelihood:            -1.4416e+05
# No. Observations:              103904   AIC:                         2.883e+05
# Df Residuals:                  103902   BIC:                         2.883e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       1.1979      0.008    147.780      0.000       1.182       1.214
# ...

# %% [markdown]
# > En este modelo podemos visualizar que a medida que aumente la satisfaccion por la
# comodidad del asiento ('Seat_comfort') aumentará la satisfaccion en limpieza ('Cleanliness') un 68%.
#
# > Entonces, podemos afirmar que están relacionados, a pesar de que su  R² no sea muy alto, su Pvalue si es bajo y sus intervalos no contienen al "0".
